# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt

# %%
# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# Display the DataFrame
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # data types

# %%
# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# Display the data types of each column
print(titanic_data.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Read Titanic dataset, inspect and export to Excel#

# %%
# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# Replace "titanic.xlsx" with the desired name for the Excel file
titanic_data.to_excel("titanic.xlsx", sheet_name="passengers", index=False)

# %%
# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# Display the first 5 rows (head) of the DataFrame
print("First 5 rows:")
print(titanic_data.head())

# Display the last 5 rows (tail) of the DataFrame
print("\nLast 5 rows:")
print(titanic_data.tail())

# Replace "titanic.xlsx" with the desired name for the Excel file
titanic_data.to_excel("titanic.xlsx", sheet_name="TitanicDAta", index=False)
# Out:
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # data info

# %%
# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic_data = pd.read_csv("Titanic-Dataset.csv")

# Display technical summary of the DataFrame
print(titanic_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
# Selecting the "Age" columnn

# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic = pd.read_csv("Titanic-Dataset.csv")

ages = titanic["Age"]

# Display the first few rows
print("Selected 'Age' column:")
print(ages.head())
# Out:
# Selected 'Age' column:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
# Selecting passengers older than 35
above_35 = titanic[titanic["Age"] > 35]

# Display the first few rows
print("\nPassengers older than 35:")
print(above_35.head())
# Out:
# Passengers older than 35:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
# Selecting passengers older than 35
above_35 = titanic[titanic["Age"] > 35]

# Display the first few rows
print("\nPassengers older than 35:")
print(above_35.head())
# Out:
# Passengers older than 35:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
# Selecting passengers from cabin class 2 and 3
class_23 = titanic[titanic["Pclass"].isin([2, 3])]

# Display the first few rows
print("\nPassengers from cabin class 2 and 3:")
print(class_23.head())
# Out:
# Passengers from cabin class 2 and 3:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
# Selecting rows where the age is known
age_no_na = titanic[titanic["Age"].notna()]

# Display the first few rows
print("\nRows with known age values:")
print(age_no_na.head())
# Out:
# Rows with known age values:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# Selecting names of passengers older than 35
adult_names = titanic.loc[titanic["Age"] > 35, "Name"]

# Display the first few names
print("\nNames of passengers older than 35:")
print(adult_names.head())
# Out:
# Names of passengers older than 35:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %% [markdown]
# # plots

# %%
# Replace "Titanic-Dataset.csv" with the actual name of your CSV file
titanic_data = pd.read_csv("Titanic-Dataset.csv")

titanic_data.plot()
plt.show()

# %%
columns_to_plot = ["Age", "Fare"]
titanic_data[columns_to_plot].plot()
plt.show()

# %%
survived_plot = titanic_data[titanic_data["Survived"] == 1].plot.scatter(x="Age", y="Fare", alpha=0.5, label="Survived")
titanic_data[titanic_data["Survived"] == 0].plot.scatter(x="Age", y="Fare", alpha=0.5, label="Did Not Survive", ax=survived_plot)
plt.legend()
plt.show()

# %%
selected_columns = ["Age", "Fare"]
fig, axs = plt.subplots(figsize=(12, 4))
titanic_data[selected_columns].plot.area(ax=axs)
axs.set_ylabel("Values")
plt.show()

# %% [markdown]
# # creating a new column

# %%
# Create a new column by assigning the output to the DataFrame
titanic_data["Fare_10_percent_more"] = titanic_data["Fare"] * 1.1

# Display the updated DataFrame
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_10_percent_more
# 0      0         A/5 21171   7.2500   NaN        S               7.97500
# 1      0          PC 17599  71.2833   C85        C              78.41163
# 2      0  STON/O2. 3101282   7.9250   NaN        S               8.71750
# ...

# %% [markdown]
# # Creating ratios

# %%
# Create a new column with the ratio
titanic_data["Age_to_Fare_ratio"] = titanic_data["Age"] / titanic_data["Fare"]

# Display the updated DataFrame
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_10_percent_more  \
# 0      0         A/5 21171   7.2500   NaN        S               7.97500
# 1      0          PC 17599  71.2833   C85        C              78.41163
# 2      0  STON/O2. 3101282   7.9250   NaN        S               8.71750
# ...

# %% [markdown]
# # Renaming Columns

# %%
# Rename the columns using a dictionary
titanic_data = titanic_data.rename(columns={
    "Pclass": "Passenger_Class",
    "SibSp": "Siblings_Spouses_on_Board",
    "Parch": "Parents_Children_on_Board"
})

# Display the updated DataFrame
titanic_data.head()
# Out:
#    PassengerId  Survived  Passenger_Class  \
# 0            1         0                3
# 1            2         1                1
# 2            3         1                3
# 3            4         1                1
# 4            5         0                3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    Siblings_Spouses_on_Board  Parents_Children_on_Board            Ticket  \
# 0                          1                          0         A/5 21171
# 1                          1                          0          PC 17599
# 2                          0                          0  STON/O2. 3101282
# ...

# %% [markdown]
# # Summary Statistics

# %%
import pandas as pd

# Load the Titanic dataset
titanic = pd.read_csv("Titanic-Dataset.csv")

# Display the first 5 rows of the dataset
print(titanic.head())

# Calculate Summary Statistics

# Average Age of Titanic Passengers
average_age = titanic["Age"].mean()
print("Average Age:", average_age)

# Median Age and Ticket Fare
median_age_fare = titanic[["Age", "Fare"]].median()
print("Median Age and Fare:")
print(median_age_fare)

# Descriptive Statistics for Age and Fare
desc_stats = titanic[["Age", "Fare"]].describe()
print("Descriptive Statistics:")
print(desc_stats)

# Aggregating Statistics for Age (min, max, median, skew) and Fare (min, max, median, mean)
agg_stats = titanic.agg(
    {
        "Age": ["min", "max", "median", "skew"],
        "Fare": ["min", "max", "median", "mean"],
    }
)
print("Aggregating Statistics:")
print(agg_stats)

# Aggregating Statistics Grouped by Category

# Average Age for Male vs. Female Passengers
avg_age_gender = titanic[["Sex", "Age"]].groupby("Sex").mean()
print("Average Age for Male vs. Female Passengers:")
print(avg_age_gender)

# Mean Ticket Fare Price for Sex and Cabin Class Combinations
mean_fare_sex_class = titanic.groupby(["Sex", "Pclass"])["Fare"].mean()
print("Mean Ticket Fare Price for Sex and Cabin Class Combinations:")
print(mean_fare_sex_class)

# Count Number of Records by Category

# Number of Passengers in Each Cabin Class
passengers_per_class = titanic["Pclass"].value_counts()
print("Number of Passengers in Each Cabin Class:")
print(passengers_per_class)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
# Load the Titanic data
titanic = pd.read_csv("Titanic-Dataset.csv")

# Filter passengers who survived
survived_passengers = titanic[titanic['Survived'] == 1]

# Filter passengers in Class 1
class_1_passengers = titanic[titanic['Pclass'] == 1]

# Filter female passengers who survived
female_survivors = titanic[(titanic['Sex'] == 'female') & (titanic['Survived'] == 1)]

# Print the results
print("Passengers who survived:")
print(survived_passengers.head())

print("\nPassengers in Class 1:")
print(class_1_passengers.head())

print("\nFemale passengers who survived:")
print(female_survivors.head())
# Out:
# Passengers who survived:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# ...
